# %% [markdown]
# # Explore data
#
# - good 3D ligand similarity but bad RMSD
# - good docking score but bad RMSD
# - bad docking score but good RMSD
# - same ligand but different conformations
# - bad superposition RMSD

# %%
import pandas as pd
from opencadd.databases.klifs import setup_remote

# %%
docking_benchmark_dataset = pd.read_csv("../data/docking_benchmark_dataset.csv", index_col=0)
fred_results = pd.read_csv("../data/fred_results.csv", index_col=0)
fred_results = fred_results[fred_results["pose"] == 1]
fred_results = fred_results.sort_values("docking_score")
hybrid_results = pd.read_csv("../data/hybrid_results.csv", index_col=0)
hybrid_results = hybrid_results[hybrid_results["pose"] == 1]
hybrid_results = hybrid_results.sort_values("docking_score")
posit_results = pd.read_csv("../data/posit_results.csv", index_col=0)
posit_results = posit_results.sort_values("docking_score")
posit_results = posit_results.sort_values("posit_probability", ascending=False)
posit_template_results = pd.read_csv("../data/posit_template_results.csv", index_col=0)
posit_template_results = posit_template_results.sort_values("docking_score")
posit_template_results = posit_template_results.sort_values("posit_probability", ascending=False)
pocket_rmsd_matrix = pd.read_csv("../data/pocket_rmsd_matrix.csv", index_col=0)

# %% [markdown]
# ## Good 3D ligand similarity but bad RMSD

# %%
posit_results[
    (posit_results["shape_similarity"] >= 1.4) &
    (posit_results["rmsd"] >= 6)
].sort_values("shape_similarity", ascending=False)
# Out:
#                                                    protein_pdb_id  \
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...           2o65
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...           2o65
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...           2o3p
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...           4lmu
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...           4lmu
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...           2o63
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...           2o63
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...           2o3p
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...           4xh6
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...           2o65
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...           2o64
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...           2o64
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...           4xh6
# ...

# %%
posit_results[posit_results["ligand_pdb_id"] == "5kcx"].head(1)
# Out:
#                                                    protein_pdb_id  \
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...           4k0y
#
#                                                    ligand_pdb_id  \
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...          5kcx
#
#                                                    ligand_expo_id  pose  \
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...            6S3     1
#
#                                                         rmsd  docking_score  \
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...  7.621208     -14.955549
#
#                                                     posit_probability  \
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...               0.24
#
#                                                     fingerprint_similarity  \
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...                0.476821
#
#                                                     shape_similarity
# ...

# %%
hybrid_results[
    (hybrid_results["ligand_pdb_id"] == "5kcx") & 
    (hybrid_results["protein_pdb_id"] == "5tur")
]
# Out:
#                                                    protein_pdb_id  \
# kinoml_OEHybridDockingFeaturizer_Human_PIM1_rcs...           5tur
#
#                                                    ligand_pdb_id  \
# kinoml_OEHybridDockingFeaturizer_Human_PIM1_rcs...          5kcx
#
#                                                    ligand_expo_id  pose  \
# kinoml_OEHybridDockingFeaturizer_Human_PIM1_rcs...            6S3     1
#
#                                                         rmsd  docking_score  \
# kinoml_OEHybridDockingFeaturizer_Human_PIM1_rcs...  7.211878     -10.228388
#
#                                                     posit_probability  \
# kinoml_OEHybridDockingFeaturizer_Human_PIM1_rcs...                NaN
#
#                                                     fingerprint_similarity  \
# kinoml_OEHybridDockingFeaturizer_Human_PIM1_rcs...                 0.69863
#
#                                                     shape_similarity
# ...

# %%
fred_results[
    (fred_results["ligand_pdb_id"] == "5kcx") & 
    (fred_results["protein_pdb_id"] == "5tur")
]
# Out:
#                                                    protein_pdb_id  \
# kinoml_OEFredDockingFeaturizer_Human_PIM1_rcsb_...           5tur
#
#                                                    ligand_pdb_id  \
# kinoml_OEFredDockingFeaturizer_Human_PIM1_rcsb_...          5kcx
#
#                                                    ligand_expo_id  pose  \
# kinoml_OEFredDockingFeaturizer_Human_PIM1_rcsb_...            6S3     1
#
#                                                         rmsd  docking_score  \
# kinoml_OEFredDockingFeaturizer_Human_PIM1_rcsb_...  2.227125     -13.795989
#
#                                                     posit_probability  \
# kinoml_OEFredDockingFeaturizer_Human_PIM1_rcsb_...                NaN
#
#                                                     fingerprint_similarity  \
# kinoml_OEFredDockingFeaturizer_Human_PIM1_rcsb_...                 0.69863
#
#                                                     shape_similarity
# ...

# %%
posit_results[posit_results["ligand_pdb_id"] == "4lmu"].head(1)
# Out:
#                                                    protein_pdb_id  \
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...           3f2a
#
#                                                    ligand_pdb_id  \
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...          4lmu
#
#                                                    ligand_expo_id  pose  \
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...            QUE     1
#
#                                                         rmsd  docking_score  \
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...  1.428888     -13.452494
#
#                                                     posit_probability  \
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...               0.18
#
#                                                     fingerprint_similarity  \
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...                0.318182
#
#                                                     shape_similarity
# ...

# %%
hybrid_results[
    (hybrid_results["ligand_pdb_id"] == "4lmu") & 
    (hybrid_results["protein_pdb_id"] == "2o65")
]
# Out:
#                                                    protein_pdb_id  \
# kinoml_OEHybridDockingFeaturizer_Human_PIM1_rcs...           2o65
#
#                                                    ligand_pdb_id  \
# kinoml_OEHybridDockingFeaturizer_Human_PIM1_rcs...          4lmu
#
#                                                    ligand_expo_id  pose  \
# kinoml_OEHybridDockingFeaturizer_Human_PIM1_rcs...            QUE     1
#
#                                                         rmsd  docking_score  \
# kinoml_OEHybridDockingFeaturizer_Human_PIM1_rcs...  6.625996     -11.134052
#
#                                                     posit_probability  \
# kinoml_OEHybridDockingFeaturizer_Human_PIM1_rcs...                NaN
#
#                                                     fingerprint_similarity  \
# kinoml_OEHybridDockingFeaturizer_Human_PIM1_rcs...                0.916667
#
#                                                     shape_similarity
# ...

# %%
fred_results[
    (fred_results["ligand_pdb_id"] == "4lmu") & 
    (fred_results["protein_pdb_id"] == "2o65")
]
# Out:
#                                                    protein_pdb_id  \
# kinoml_OEFredDockingFeaturizer_Human_PIM1_rcsb_...           2o65
#
#                                                    ligand_pdb_id  \
# kinoml_OEFredDockingFeaturizer_Human_PIM1_rcsb_...          4lmu
#
#                                                    ligand_expo_id  pose  \
# kinoml_OEFredDockingFeaturizer_Human_PIM1_rcsb_...            QUE     1
#
#                                                         rmsd  docking_score  \
# kinoml_OEFredDockingFeaturizer_Human_PIM1_rcsb_...  6.665669     -13.463041
#
#                                                     posit_probability  \
# kinoml_OEFredDockingFeaturizer_Human_PIM1_rcsb_...                NaN
#
#                                                     fingerprint_similarity  \
# kinoml_OEFredDockingFeaturizer_Human_PIM1_rcsb_...                0.916667
#
#                                                     shape_similarity
# ...

# %%
posit_results[posit_results["ligand_pdb_id"] == "4rc2"].head(1)
# Out:
#                                                    protein_pdb_id  \
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...           3jya
#
#                                                    ligand_pdb_id  \
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...          4rc2
#
#                                                    ligand_expo_id  pose  \
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...            3O8     1
#
#                                                         rmsd  docking_score  \
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...  4.399345     -14.509893
#
#                                                     posit_probability  \
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...               0.33
#
#                                                     fingerprint_similarity  \
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...                0.222222
#
#                                                     shape_similarity
# ...

# %%
hybrid_results[
    (hybrid_results["ligand_pdb_id"] == "4rc2") & 
    (hybrid_results["protein_pdb_id"] == "4rc4")
]
# Out:
#                                                    protein_pdb_id  \
# kinoml_OEHybridDockingFeaturizer_Human_PIM1_rcs...           4rc4
#
#                                                    ligand_pdb_id  \
# kinoml_OEHybridDockingFeaturizer_Human_PIM1_rcs...          4rc2
#
#                                                    ligand_expo_id  pose  \
# kinoml_OEHybridDockingFeaturizer_Human_PIM1_rcs...            3O8     1
#
#                                                         rmsd  docking_score  \
# kinoml_OEHybridDockingFeaturizer_Human_PIM1_rcs...  4.230693     -12.685549
#
#                                                     posit_probability  \
# kinoml_OEHybridDockingFeaturizer_Human_PIM1_rcs...                NaN
#
#                                                     fingerprint_similarity  \
# kinoml_OEHybridDockingFeaturizer_Human_PIM1_rcs...                0.819444
#
#                                                     shape_similarity
# ...

# %%
fred_results[
    (fred_results["ligand_pdb_id"] == "4rc2") & 
    (fred_results["protein_pdb_id"] == "4rc4")
]
# Out:
#                                                    protein_pdb_id  \
# kinoml_OEFredDockingFeaturizer_Human_PIM1_rcsb_...           4rc4
#
#                                                    ligand_pdb_id  \
# kinoml_OEFredDockingFeaturizer_Human_PIM1_rcsb_...          4rc2
#
#                                                    ligand_expo_id  pose  \
# kinoml_OEFredDockingFeaturizer_Human_PIM1_rcsb_...            3O8     1
#
#                                                         rmsd  docking_score  \
# kinoml_OEFredDockingFeaturizer_Human_PIM1_rcsb_...  4.479555     -13.980396
#
#                                                     posit_probability  \
# kinoml_OEFredDockingFeaturizer_Human_PIM1_rcsb_...                NaN
#
#                                                     fingerprint_similarity  \
# kinoml_OEFredDockingFeaturizer_Human_PIM1_rcsb_...                0.819444
#
#                                                     shape_similarity
# ...

# %% [markdown]
# ## Good docking score but bad RMSD

# %%
posit_results[
    (posit_results["docking_score"] <= -20) &
    (posit_results["rmsd"] >= 4)
]
# Out:
# Empty DataFrame
# Columns: [protein_pdb_id, ligand_pdb_id, ligand_expo_id, pose, rmsd, docking_score, posit_probability, fingerprint_similarity, shape_similarity]
# Index: []

# %%
hybrid_results[
    (hybrid_results["docking_score"] <= -20) &
    (hybrid_results["rmsd"] >= 4)
]
# Out:
# Empty DataFrame
# Columns: [protein_pdb_id, ligand_pdb_id, ligand_expo_id, pose, rmsd, docking_score, posit_probability, fingerprint_similarity, shape_similarity]
# Index: []

# %%
fred_results[
    (fred_results["docking_score"] <= -20) &
    (fred_results["rmsd"] >= 4)
]
# Out:
#                                                    protein_pdb_id  \
# kinoml_OEFredDockingFeaturizer_Mouse_PKACa_rcsb...           4dg3
# kinoml_OEFredDockingFeaturizer_Mouse_PKACa_rcsb...           4dg3
# kinoml_OEFredDockingFeaturizer_Mouse_PKACa_rcsb...           4dg3
# kinoml_OEFredDockingFeaturizer_Mouse_PKACa_rcsb...           3idc
# kinoml_OEFredDockingFeaturizer_Mouse_PKACa_rcsb...           3idc
# kinoml_OEFredDockingFeaturizer_Mouse_PKACa_rcsb...           4iaz
# kinoml_OEFredDockingFeaturizer_Mouse_PKACa_rcsb...           4iaz
# kinoml_OEFredDockingFeaturizer_Mouse_PKACa_rcsb...           4iaz
# kinoml_OEFredDockingFeaturizer_Mouse_PKACa_rcsb...           4iaz
# kinoml_OEFredDockingFeaturizer_Mouse_PKACa_rcsb...           4iaz
# kinoml_OEFredDockingFeaturizer_Mouse_PKACa_rcsb...           4iaz
# kinoml_OEFredDockingFeaturizer_Mouse_PKACa_rcsb...           4iaz
# kinoml_OEFredDockingFeaturizer_Mouse_PKACa_rcsb...           4iaz
# ...

# %%
posit_template_results[
    (posit_template_results["docking_score"] <= -20) &
    (posit_template_results["rmsd"] >= 4)
]
# Out:
# Empty DataFrame
# Columns: [protein_pdb_id, ligand_pdb_id, ligand_expo_id, pose, rmsd, docking_score, posit_probability, fingerprint_similarity, shape_similarity]
# Index: []

# %% [markdown]
# ## Bad docking score but good RMSD

# %%
posit_results[
    (posit_results["rmsd"] <= 2)
].sort_values("docking_score", ascending=False).groupby("protein_pdb_id").head(1).head()
# Out:
#                                                    protein_pdb_id  \
# kinoml_OEPositDockingFeaturizer_Human_BTK_rcsb_...           5kup
# kinoml_OEPositDockingFeaturizer_Human_AurA_rcsb...           5aae
# kinoml_OEPositDockingFeaturizer_Human_AurA_rcsb...           6vpm
# kinoml_OEPositDockingFeaturizer_Human_AurA_rcsb...           2w1f
# kinoml_OEPositDockingFeaturizer_Human_JAK2_rcsb...           6vsn
#
#                                                    ligand_pdb_id  \
# kinoml_OEPositDockingFeaturizer_Human_BTK_rcsb_...          5j87
# kinoml_OEPositDockingFeaturizer_Human_AurA_rcsb...          2x6d
# kinoml_OEPositDockingFeaturizer_Human_AurA_rcsb...          6vpl
# kinoml_OEPositDockingFeaturizer_Human_AurA_rcsb...          2w1g
# kinoml_OEPositDockingFeaturizer_Human_JAK2_rcsb...          6vnc
#
#                                                    ligand_expo_id  pose  \
# kinoml_OEPositDockingFeaturizer_Human_BTK_rcsb_...            N42     1
# ...

# %%
hybrid_results[
    (hybrid_results["rmsd"] <= 2)
].sort_values("docking_score", ascending=False).groupby("protein_pdb_id").head(1).head()
# Out:
#                                                    protein_pdb_id  \
# kinoml_OEHybridDockingFeaturizer_Human_BTK_rcsb...           5j87
# kinoml_OEHybridDockingFeaturizer_Human_IRAK4_rc...           7c2v
# kinoml_OEHybridDockingFeaturizer_Human_BTK_rcsb...           4z3v
# kinoml_OEHybridDockingFeaturizer_Human_IRAK4_rc...           6vql
# kinoml_OEHybridDockingFeaturizer_Human_BTK_rcsb...           5fbn
#
#                                                    ligand_pdb_id  \
# kinoml_OEHybridDockingFeaturizer_Human_BTK_rcsb...          6hrt
# kinoml_OEHybridDockingFeaturizer_Human_IRAK4_rc...          6thz
# kinoml_OEHybridDockingFeaturizer_Human_BTK_rcsb...          6tfp
# kinoml_OEHybridDockingFeaturizer_Human_IRAK4_rc...          6o94
# kinoml_OEHybridDockingFeaturizer_Human_BTK_rcsb...          6x3o
#
#                                                    ligand_expo_id  pose  \
# kinoml_OEHybridDockingFeaturizer_Human_BTK_rcsb...            GMW     1
# ...

# %%
fred_results[
    (fred_results["rmsd"] <= 2)
].sort_values("docking_score", ascending=False).groupby("protein_pdb_id").head(1).head()
# Out:
#                                                    protein_pdb_id  \
# kinoml_OEFredDockingFeaturizer_Human_MST3_rcsb_...           4qmu
# kinoml_OEFredDockingFeaturizer_Human_TRKA_rcsb_...           5kmn
# kinoml_OEFredDockingFeaturizer_Mouse_PKACa_rcsb...           6mm6
# kinoml_OEFredDockingFeaturizer_Mouse_PKACa_rcsb...           6mm7
# kinoml_OEFredDockingFeaturizer_Human_BTK_rcsb_6...           6di5
#
#                                                    ligand_pdb_id  \
# kinoml_OEFredDockingFeaturizer_Human_MST3_rcsb_...          4qmx
# kinoml_OEFredDockingFeaturizer_Human_TRKA_rcsb_...          6nss
# kinoml_OEFredDockingFeaturizer_Mouse_PKACa_rcsb...          4ib3
# kinoml_OEFredDockingFeaturizer_Mouse_PKACa_rcsb...          6mm8
# kinoml_OEFredDockingFeaturizer_Human_BTK_rcsb_6...          4zly
#
#                                                    ligand_expo_id  pose  \
# kinoml_OEFredDockingFeaturizer_Human_MST3_rcsb_...            H8H     1
# ...

# %%
posit_template_results[
    (posit_template_results["rmsd"] <= 2)
].sort_values("docking_score", ascending=False).groupby("protein_pdb_id").head(1).head()
# Out:
#                                                    protein_pdb_id  \
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...           4wsy
# kinoml_OEPositDockingFeaturizer_Human_TRKA_rcsb...           6nss
# kinoml_OEPositDockingFeaturizer_Human_IRAK4_rcs...           5k7g
# kinoml_OEPositDockingFeaturizer_Human_JAK2_rcsb...           5usy
# kinoml_OEPositDockingFeaturizer_Human_JAK2_rcsb...           4aqc
#
#                                                    ligand_pdb_id  \
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...          4alv
# kinoml_OEPositDockingFeaturizer_Human_TRKA_rcsb...          6pl4
# kinoml_OEPositDockingFeaturizer_Human_IRAK4_rcs...          6uya
# kinoml_OEPositDockingFeaturizer_Human_JAK2_rcsb...          7ree
# kinoml_OEPositDockingFeaturizer_Human_JAK2_rcsb...          7ree
#
#                                                    ligand_expo_id  pose  \
# kinoml_OEPositDockingFeaturizer_Human_PIM1_rcsb...            R9P     1
# ...

# %% [markdown]
# ## Same ligand but different conformations

# %%
remote = setup_remote()
all_structures = remote.structures.all_structures()

# %%
kinase_ligand_conformation_dict = {}
for i, row in all_structures.iterrows():
    kinase_klifs_id = row["kinase.klifs_id"]
    conformation = f"{row['structure.dfg']}/{row['structure.ac_helix']}"
    if "na" in conformation:
        continue
    pdb_id = row["structure.pdb_id"]
    expo_id = row["ligand.expo_id"]
    if expo_id == "-":
        continue
    if kinase_klifs_id not in kinase_ligand_conformation_dict.keys():
        kinase_ligand_conformation_dict[kinase_klifs_id] = {}
    if expo_id not in kinase_ligand_conformation_dict[kinase_klifs_id].keys():
        kinase_ligand_conformation_dict[kinase_klifs_id][expo_id] = {}
    if conformation not in kinase_ligand_conformation_dict[kinase_klifs_id][expo_id].keys():
        kinase_ligand_conformation_dict[kinase_klifs_id][expo_id][conformation] = pdb_id

# %%
for klifs_kinase_id, ligands in kinase_ligand_conformation_dict.items():
    for expo_id, conformations in ligands.items():
        if len(conformations.keys()) > 2:
            print(klifs_kinase_id, expo_id, conformations)
# Out:
# 109 ATP {'in/in': '4fg7', 'out-like/out': '4fg8', 'in/out': '4fg9'}
# 242 OWQ {'out-like/out': '6yky', 'out-like/in': '6yky', 'in/in': '6yky'}
# 242 OXW {'out-like/out': '6ylc', 'in/in': '6ylc', 'out-like/in': '6ylc'}
# 259 ACP {'out/in': '6c83', 'in/in': '6cpf', 'out-like/in': '4c3r'}
# 259 ADN {'in/in': '4o0s', 'out/in': '1muo', 'out-like/in': '4o0u'}
# 289 F9N {'in/in': '6s73', 'in/out': '6s75', 'out-like/out': '6s75'}
# 345 STU {'out-like/out': '2clq', 'in/in': '4bf2', 'in/out': '4bf2', 'out-like/in': '2clq'}
# 358 B49 {'in/out': '6ng0', 'in/in': '6nfz', 'out/out': '6ng0'}

# %% [markdown]
# ## Bad superposition RMSD

# %%
pocket_rmsd_matrix.max().max()
# Out:
# 3.348400769849015

# %%
def get_pocket_rmsd(pdb_id1, pdb_id2, docking_benchmark_dataset=docking_benchmark_dataset, pocket_rmsd_matrix=pocket_rmsd_matrix):
    """Retrieve the KLIFS pocket RMSD from two kinase structures."""
    structure_klifs_id1 = docking_benchmark_dataset[
        docking_benchmark_dataset["structure.pdb_id"] == pdb_id1
    ]["structure.klifs_id"].iloc[0]
    structure_klifs_id2 = docking_benchmark_dataset[
        docking_benchmark_dataset["structure.pdb_id"] == pdb_id2
    ]["structure.klifs_id"].iloc[0] 
    pocket_rmsd = pocket_rmsd_matrix[str(structure_klifs_id1)][structure_klifs_id2]
    return pocket_rmsd

# %%
fred_results["pocket_rmsd"] = fred_results.apply(lambda row: get_pocket_rmsd(row["protein_pdb_id"], row["ligand_pdb_id"]), axis=1)

# %%
fred_results[
    (fred_results["rmsd"] > 25) &
    (fred_results["rmsd"] > 2.0)
].head(30)
# Out:
#                                                    protein_pdb_id  \
# kinoml_OEFredDockingFeaturizer_Human_AurA_rcsb_...           6vpl
# kinoml_OEFredDockingFeaturizer_Human_AurA_rcsb_...           4c3p
# kinoml_OEFredDockingFeaturizer_Human_AurA_rcsb_...           4c3p
# kinoml_OEFredDockingFeaturizer_Human_AurA_rcsb_...           4c3p
# kinoml_OEFredDockingFeaturizer_Human_AurA_rcsb_...           4c3p
# kinoml_OEFredDockingFeaturizer_Human_AurA_rcsb_...           4c3p
# kinoml_OEFredDockingFeaturizer_Human_AurA_rcsb_...           4c3p
# kinoml_OEFredDockingFeaturizer_Human_AurA_rcsb_...           4c3p
# kinoml_OEFredDockingFeaturizer_Human_AurA_rcsb_...           4c3p
# kinoml_OEFredDockingFeaturizer_Human_AurA_rcsb_...           4c3p
# kinoml_OEFredDockingFeaturizer_Human_AurA_rcsb_...           4c3p
# kinoml_OEFredDockingFeaturizer_Human_AurA_rcsb_...           4c3p
# kinoml_OEFredDockingFeaturizer_Human_AurA_rcsb_...           4c3p
# ...
